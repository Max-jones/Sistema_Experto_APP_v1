# %%
import pandas as pd
import sklearn
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
import os
import sys
notebook_path = os.path.join('..')
module_path = os.path.abspath(notebook_path)
print('This directory', notebook_path)
print("Current Directory", module_path)
 
if module_path not in sys.path:
    sys.path.append(module_path)

    
# from src.load_local_data import load_data
# Out:
# This directory ..
# Current Directory c:\Users\elmha\OneDrive - Universidad de Chile\GitHub\Sistema_Experto_APP_v1

# %%
import os
import sys
notebook_path = os.path.join('..')
module_path = os.path.abspath(notebook_path)
print('This directory', notebook_path)
print("Current Directory", module_path)
if module_path not in sys.path:
    sys.path.append(module_path)
from src.data.load_dataset import load_data
# Out:
# This directory ..
# Current Directory c:\Users\elmha\OneDrive - Universidad de Chile\GitHub\Sistema_Experto_APP_v1

# %%
path = os.getcwd()
print("Current Directory", path)
 
parent_directory = os.path.dirname(path)
print("Parent Directory", parent_directory)

data_directory = parent_directory + '\data'
print("Data Directory", data_directory)
# Out:
# Current Directory c:\Users\elmha\OneDrive - Universidad de Chile\GitHub\Sistema_Experto_APP_v1\notebooks
# Parent Directory c:\Users\elmha\OneDrive - Universidad de Chile\GitHub\Sistema_Experto_APP_v1
# Data Directory c:\Users\elmha\OneDrive - Universidad de Chile\GitHub\Sistema_Experto_APP_v1\data

# %%
def load_data(file):
    '''
    Carga un dataset artificial desde un dataframe de pandas
    
    '''

    dataset = pd.read_csv(file, sep=';', decimal=',')
    dataset.set_index("Date_Time", inplace=True)
    # chile = pytz.timezone("Chile/Continental")
    # dataset.index = data.index.tz_localize(pytz.utc).tz_convert(chile)
    return dataset

# %%
local_path = data_directory + '\Horcon_1_etiqueta.csv'

dataframe_original = load_data(local_path)
dataframe_original.head()
# Out:
#                      Pression [cm H2O]  Temperatura [°C]  EC [µs/cm]  \
# Date_Time
# 2013-02-03 13:00:00              981.5             17.81         257
# 2013-02-03 14:00:00              871.1             17.86           9
# 2013-02-03 15:00:00              870.7             17.80           9
# 2013-02-03 16:00:00             1025.5             17.71         256
# 2013-02-03 17:00:00              870.3             17.84           9
#
#                      etiqueta conjunta
# Date_Time
# 2013-02-03 13:00:00                  1
# 2013-02-03 14:00:00                  1
# 2013-02-03 15:00:00                  1
# 2013-02-03 16:00:00                  1
# 2013-02-03 17:00:00                  1

# %%
path = os.getcwd()
print("Current Directory", path)
 
parent_directory = os.path.dirname(path)
print("Parent Directory", parent_directory)

data_directory = parent_directory + '\data'
print("Data Directory", data_directory)

artificial_data_directory = data_directory + '\\artificiales'
# Out:
# Current Directory c:\Users\elmha\OneDrive - Universidad de Chile\GitHub\Sistema_Experto_APP_v1\notebooks
# Parent Directory c:\Users\elmha\OneDrive - Universidad de Chile\GitHub\Sistema_Experto_APP_v1
# Data Directory c:\Users\elmha\OneDrive - Universidad de Chile\GitHub\Sistema_Experto_APP_v1\data

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(artificial_data_directory) if isfile(join(artificial_data_directory, f))]
# print(artificial_data_directory)

# %%
onlyfiles[0]
# Out:
# 'Pozo_1_Labeled.csv'

# %%
pozos_artificiales = [onlyfiles[1], onlyfiles[3], onlyfiles[5]]

# %%
artificial_data_directory + '\\' + pozos_artificiales[0]
# Out:
# 'c:\\Users\\elmha\\OneDrive - Universidad de Chile\\GitHub\\Sistema_Experto_APP_v1\\data\\artificiales\\pozo_1_procesado.csv'

# %%
# #Gráficos chayas
# from matplotlib import rcParams
# import numpy as np
# import decimal as D


# colors = ["#b20710","#07b140","#4c31e0"]
# df_names = {'df1', 'df2', 'df3'}

# for f,c, name in zip(pozos_artificiales, colors, df_names):
    
#     file_dir = artificial_data_directory+'\\'+f

#     df = load_data(file_dir)
#     dataset = pd.read_csv(file_dir, sep=';', decimal=',')
#     dataset.set_index("Date_Time", inplace=True)
#     dataset
#     rcParams["font.size"] = 15

#     fig, ax = plt.subplots(3, 1, figsize=(20, 20),)

#     variables = ["Pres", "pH", "Temp"]

#     print(name)
#     for var, axes in zip(variables, ax):
#         print(var)
#         # axes.set(xlabel='', title=var.title())
#         axes.plot(df.index, df[var], color=c)

#     plt.show()
# Out:
# df1
# Pres
# pH
# Temp
# df2
# Pres
# pH
# Temp
# df3
# Pres
# pH
# Temp

# %%
df
# Out:
#                      Pression [cm H2O]  Temperatura [°C]  EC [µs/cm]  \
# Date_Time
# 2013-02-03 13:00:00              981.5             17.81         257
# 2013-02-03 14:00:00              871.1             17.86           9
# 2013-02-03 15:00:00              870.7             17.80           9
# 2013-02-03 16:00:00             1025.5             17.71         256
# 2013-02-03 17:00:00              870.3             17.84           9
# ...                                ...               ...         ...
# 2017-02-20 11:00:00             1034.4             22.92           0
# 2017-02-20 12:00:00             1034.0             23.44           0
# 2017-02-20 13:00:00             1034.2             22.66           0
# 2017-02-20 14:00:00             1034.6             22.51           0
# 2017-02-20 15:00:00             1035.0             24.23           0
#
#                      etiqueta conjunta
# Date_Time
# 2013-02-03 13:00:00                  1
# 2013-02-03 14:00:00                  1
# 2013-02-03 15:00:00                  1
# 2013-02-03 16:00:00                  1
# 2013-02-03 17:00:00                  1
# ...                                ...
# 2017-02-20 11:00:00                  1
# 2017-02-20 12:00:00                  1
# 2017-02-20 13:00:00                  1
# 2017-02-20 14:00:00                  1
# 2017-02-20 15:00:00                  1
#
# [34827 rows x 4 columns]

# %%
df =dataframe_original

# %%
time_window = df.loc['15-08-2015':'15-01-2017']

# %%
time_window.sort_index(inplace=True)

# %%
time_window['EC [µs/cm]'].plot()
display(time_window.head())
# time_window.index
# Out:
#                      Pression [cm H2O]  Temperatura [°C]  EC [µs/cm]  \
# Date_Time
# 2015-08-15 00:00:00             1377.7             14.83         297
# 2015-08-15 01:00:00             1213.5             14.70         296
# 2015-08-15 02:00:00             1123.7             15.02         300
# 2015-08-15 03:00:00             1251.8             15.16         299
# 2015-08-15 04:00:00             1296.3             15.14         300
#
#                      etiqueta conjunta
# Date_Time
# 2015-08-15 00:00:00                  0
# 2015-08-15 01:00:00                  0
# 2015-08-15 02:00:00                  0
# 2015-08-15 03:00:00                  0
# 2015-08-15 04:00:00                  0

# %%
a  = time_window.loc[time_window['etiqueta conjunta'] == 1] #anomaly
