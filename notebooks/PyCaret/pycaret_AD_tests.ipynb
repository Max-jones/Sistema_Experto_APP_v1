# %%
from pycaret.datasets import get_data
anomaly = get_data('anomaly')
from pycaret.anomaly import *
exp_name = setup(data = anomaly)
knn = create_model('knn')
plot_model(knn, plot = )
# %%
# Out:
# <div>                            <div id="cba65d8b-298f-4def-843f-8fb2085c0ebf" class="plotly-graph-div" style="height:800px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cba65d8b-298f-4def-843f-8fb2085c0ebf")) {                    Plotly.newPlot(                        "cba65d8b-298f-4def-843f-8fb2085c0ebf",                        [{"customdata": [[0.263995357], [0.546092303], [0.336714104], [0.092107835], [0.325261175], [0.212464853], [0.258565714], [0.869236755], [0.197077957], [0.292984504], [0.82178316], [0.796622959], [0.045577011], [0.613660351], [0.950744566], [0.336346337], [0.034440667], [0.741544275], [0.18443265], [0.664514943], [0.162824858], [0.729838445], [0.62837389], [0.057883661], [0.445534827], [0.80183695], [0.27709612], [0.228634015], [0.834860657], [0.669766511], [0.53
# ...

# %%
local_path = 'C:\\Users\\elmha\\OneDrive - Universidad de Chile\GitHub\Sistema_Experto_APP\data\Horcon-etiquetado_con_1_etiqueta.csv'
import pytz
import pandas as pd

def load_data(path):
    '''
    ARGS: path to the local .csv file
    Load data and search for the Date_Time column to index the dataframe by a datetime value.

    '''
    data = pd.read_csv(path, sep=';')
    data.head()
    data['Date_Time'] = pd.to_datetime(data['Date_Time'])
    data.set_index('Date_Time', inplace=True)
    chile=pytz.timezone('Chile/Continental')
    data.index = data.index.tz_localize(pytz.utc).tz_convert(chile)
    return data

# %%
datas = load_data(local_path)
datas.head()
# Out:
#                            Pression [cm H2O]  Temperatura [°C]  EC [µs/cm]  \
# Date_Time
# 2013-02-03 10:00:00-03:00              981.5             17.81         257
# 2013-02-03 11:00:00-03:00              871.1             17.86           9
# 2013-02-03 12:00:00-03:00              870.7             17.80           9
# 2013-02-03 13:00:00-03:00             1025.5             17.71         256
# 2013-02-03 14:00:00-03:00              870.3             17.84           9
#
#                            etiqueta conjunta
# Date_Time
# 2013-02-03 10:00:00-03:00                  1
# 2013-02-03 11:00:00-03:00                  1
# 2013-02-03 12:00:00-03:00                  1
# 2013-02-03 13:00:00-03:00                  1
# 2013-02-03 14:00:00-03:00                  1

# %%
datas_wol = datas.drop(labels=['Etiqueta P','Etiqueta EC','Etiqueta T'], axis=1)
datas_wol.head()
# Out:
#                            Pression [cm H2O]  Temperatura [°C]  EC [µs/cm]
# Date_Time
# 2013-03-02 10:00:00-03:00              981.5             17.81         257
# 2013-03-02 11:00:00-03:00              871.1             17.86           9
# 2013-03-02 12:00:00-03:00              870.7             17.80           9
# 2013-03-02 13:00:00-03:00             1025.5             17.71         256
# 2013-03-02 14:00:00-03:00              870.3             17.84           9

# %%
from pycaret.anomaly import *
anomaly_detection = setup(data = datas,silent=True,profile=True, use_gpu=True)
# knn = create_model('knn')
# plot_model(knn, plot = 'tsne')
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.88it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-11-29 17:28:56.434825&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
datas
# Out:
#       Date_Time;Pression [cm H2O];Temperatura [°C];EC [µs/cm];etiqueta conjunta
# 0                     02-03-2013 13:00;981.5;17.81;257;1
# 1                       02-03-2013 14:00;871.1;17.86;9;1
# 2                        02-03-2013 15:00;870.7;17.8;9;1
# 3                    02-03-2013 16:00;1025.5;17.71;256;1
# 4                       02-03-2013 17:00;870.3;17.84;9;1
# ...                                                  ...
# 34822                  20-02-2017 11:00;1034.4;22.92;0;1
# 34823                    20-02-2017 12:00;1034;23.44;0;1
# 34824                  20-02-2017 13:00;1034.2;22.66;0;1
# 34825                  20-02-2017 14:00;1034.6;22.51;0;1
# 34826                    20-02-2017 15:00;1035;24.23;0;1
#
# [34827 rows x 1 columns]

# %%
anomaly_methods= ['abod','iforest', 'cluster', 'cof', 'histogram', 'knn', 'lof', 'svm', 'pca', ' mcd', 'sod', 'sos']
svm=create_model('svm',fraction=0.1)

# %%
evaluate_model(svm)

# %%
anomaly_detection = setup(data = datas,silent=True,profile=True, use_gpu=True)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Anomaly TSnE (3d)', 'tsn…
# IntProgress(value=0, description='Processing: ', max=5)

# %%
tuned_svm = tune_model(model='svm', supervised_target='etiqueta conjunta')
# Out:
# IntProgress(value=0, description='Processing: ', max=74)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            14:36:56
# Status     . . . . . . . . . . . . . . . . . .    Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  LogisticRegression
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38244/4272296834.py in <module>
# ----> 1 tuned_svm = tune_model(model='svm', supervised_target='etiqueta conjunta')
#
# ~\anaconda3\envs\se_venv\lib\site-packages\pycaret\anomaly.py in tune_model(model, supervised_target, supervised_type, supervised_estimator, method, optimize, custom_grid, fold, fit_kwargs, groups, round, verbose)
#     812     """
#     813
# --> 814     return pycaret.internal.tabular.tune_model_unsupervised(
#     815         model=model,
#     816         supervised_target=supervised_target,
#
# ...

# %% [markdown]
# # t-distributed stochastic neighbor embedding

# %%
from pycaret.classification import *

s = setup(datas, target = 'etiqueta conjunta', session_id = 123, silent = True, use_gpu = True)
best = compare_models()


best_score_grid = best.pull()

best_score_grid
# Out:
# <style  type="text/css" >
#     #T_dbe18_ th {
#           text-align: left;
# ...

# %%
pull()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# catboost              CatBoost Classifier    0.9662  0.9860  0.7761  0.9065
# lightgbm  Light Gradient Boosting Machine    0.9658  0.9845  0.7672  0.9114
# xgboost         Extreme Gradient Boosting    0.9644  0.9855  0.7724  0.8933
# rf               Random Forest Classifier    0.9641  0.9788  0.7576  0.9048
# et                 Extra Trees Classifier    0.9619  0.9744  0.7304  0.9091
# dt               Decision Tree Classifier    0.9536  0.8847  0.7956  0.7890
# gbc          Gradient Boosting Classifier    0.9500  0.9619  0.5846  0.9460
# knn                K Neighbors Classifier    0.9342  0.8461  0.5194  0.8243
# ada                  Ada Boost Classifier    0.9323  0.8960  0.4467  0.8898
# lda          Linear Discriminant Analysis    0.9247  0.6902  0.3228  1.0000
# lr                    Logistic Regression    0.9246  0.7272  0.3220  1.0000
# ...

# %%
best.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27564/451564920.py in <module>
# ----> 1 best.plot_predictions()
#
# TypeError: plot_predictions() missing 2 required positional arguments: 'data' and 'features_to_change'
